# %%
#%%
# Section of the Python code where we import all dependencies on third party Python modules/libaries or our own
# libraries (exposed C++ code to Python, i.e. darts.engines && darts.physics)
from model_deadoil import ModelDA
import numpy as np
import meshio
from darts.engines import *

import concurrent.futures
import math
import os
import re
import shutil
import time

import matplotlib.pyplot as plt
import matplotlib.colors as colors
import matplotlib.cm as cm
import pandas as pd
import scipy.stats as stats

# %%
#%%
#function to get an angle and output apertures 
DIR = 'mesh_files'
scale = 15
mesh_file = os.path.join(DIR, 'mesh_{:}_real_6.msh'.format(scale))
mesh_data = meshio.read(mesh_file)
num_frac = mesh_data.cells[0].data.shape[0]
act_frac_sys = np.zeros((num_frac, 4))

def aperture_vec(rotation):
    def calc_aperture(sigma_n):
        JRC = 7.225
        JCS = 17.5
        e_0 = 0.15
        v_m = -0.1032 - 0.0074 * JRC + 1.135 * (JCS / e_0) ** -0.251
        K_ni = -7.15 + 1.75 * JRC + 0.02 * JCS / e_0
        return e_0 - (1 / v_m + K_ni / sigma_n) ** -1


    DIR = 'mesh_files'
    scale = 15
    mesh_file = os.path.join(DIR, 'mesh_{:}_real_6.msh'.format(scale))
    mesh_data = meshio.read(mesh_file)
    num_frac = mesh_data.cells[0].data.shape[0]
    act_frac_sys = np.zeros((num_frac, 4))

    for ii in range(num_frac):
        ith_line = mesh_data.points[mesh_data.cells[0].data[ii][:2]]
        act_frac_sys[ii, :2] = ith_line[0, :2]
        act_frac_sys[ii, 2:] = ith_line[1, :2]

    # Plot to check if it worked:
    #plt.figure()
    #plt.plot(np.array([act_frac_sys[:, 0], act_frac_sys[:, 2]]),
    #         np.array([act_frac_sys[:, 1], act_frac_sys[:, 3]]), color='black')
    #plt.show()

    epsilon = 1e-4
    dx = act_frac_sys[:, 0] - act_frac_sys[:, 2] + epsilon * np.random.rand(num_frac)
    dy = act_frac_sys[:, 1] - act_frac_sys[:, 3] + epsilon * np.random.rand(num_frac)
    #rotation = 0
    angles = np.arctan(dy / dx) * 180 / np.pi + rotation + epsilon * np.random.rand(num_frac)
    sigma_H = 5
    sigma_h = 1
    sigma_n = (sigma_H + sigma_h) / 2 + (sigma_H + sigma_h) / 2 * np.cos(angles * np.pi / 180 * 2)
    factor_aper = 2.5
    fracture_aper = calc_aperture(sigma_n) * 1e-3 * factor_aper
    fracture_aper[fracture_aper < 1e-9] = 1e-9
    fracture_aper[fracture_aper > 0.15 * 1e-3 * factor_aper] = 0.15 * 1e-3 * factor_aper

    m_to_mm = 1e3
    min_aper = 1e-9 * m_to_mm
    max_aper = 0.15 * 1e-3 * factor_aper * m_to_mm
    fracs = fracture_aper * m_to_mm
    fracs[fracs < min_aper] = min_aper
    fracs[fracs > max_aper] = max_aper
    #norm = colors.Normalize(min_aper, max_aper)
    #colors_aper = cm.viridis(norm(fracs))
    #cutoff_value = min_aper

    #comement lines below
    #fig, ax = plt.subplots(1, 1, figsize=(10, 10), dpi=400, facecolor='w', edgecolor='k')
    #for ii in range(len(fracs)):
    #    if fracs[ii] >= cutoff_value:
    #        ax.plot(np.array([act_frac_sys[ii, 0], act_frac_sys[ii, 2]]),
    #                np.array([act_frac_sys[ii, 1], act_frac_sys[ii, 3]]),
    #                 color=colors_aper[ii, :-1])

    #ax.axis('equal')

    #for tick in ax.xaxis.get_major_ticks():
    #    tick.label.set_fontsize(14)
    #for tick in ax.yaxis.get_major_ticks():
    #    tick.label.set_fontsize(14)

    #sm = plt.cm.ScalarMappable(cmap=cm.viridis, norm=norm)
    #sm._A = []
    #cbar = plt.colorbar(sm)
    #cbar.set_label(r'Aperture, $a$ [mm]')

    #plt.tight_layout()
    #plt.savefig("variable_aperture_base_case_scale_{:}.pdf".format(scale))
    #plt.show()
    return np.array(fracture_aper)

# %%
aperture_vec(90).shape
# Out:
# (1370,)

# %%
#%%
#First we define the model that will be used as refference with a 8138 distribution of fracture appertures - np.array with 8138 elements distributed from a uniform distribution
angle_ref = 45 #degress
NFractures = aperture_vec(angle_ref).shape[0]
frac_aper_het =  np.zeros(NFractures)
frac_aper_het = aperture_vec(angle_ref) #np.clip(np.random.normal(1e-3, 0.1*(1e-3), NFractures),0.0005,0.0015)
plt.hist(frac_aper_het, bins=200)
plt.title(f'{aperture_vec(angle_ref).shape[0]} fracture appertures for the refrence model with {angle_ref} degrees')
plt.show()

# %%
frac_aper_het.mean()
# Out:
# 3.316327058090797e-05

# %%
#%%
#First we define the model that will be used as refference frac_aper = = 1e-3 (base case produced by Stephan)
# 
m_true = ModelDA(frac_aper =aperture_vec(angle_ref))
time_range = np.arange(0,1000, 10)+1
# After constructing the model, the simulator needs to be initialized. The init() class method is called, which is
# inherited (https://www.python-course.eu/python3_inheritance.php) from the parent class DartsModel (found in
# darts/models/darts_model.py (NOTE: This is not the same as the__init__(self, **) method which each class (should)
# have).

m_true.init()
# Specify some other time-related properties (NOTE: all time parameters are in [days])
m_true.params.max_ts = 1  # Adjust the maximum time-step as desired (this is overwriting the max_ts specified in model.py)
m_true.run(time_range[-1])
# Out:
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8

# %%
import pandas as pd
time_data = pd.DataFrame.from_dict(m_true.physics.engine.time_data)
writer = pd.ExcelWriter('m_true_time_data.xlsx')
time_data.to_excel(writer, 'Sheet1')
writer.save()

# %%
from darts.tools.plot_darts import *
prod = m_true.reservoir.wells[1]
inj =   m_true.reservoir.wells[0]
ax2 = plot_oil_rate_darts(prod.name, time_data)

# %%
ax3 = plot_watercut_darts(prod.name, time_data)

# %%
# data colums
columnsNameList = ['P1 : oil rate (m3/day)']
#create a function that store the mean of the data in a array X of Y elements that are between two values a and b
def media_function(time_range, time_data,columnsNameList):
    media =[]
    i= 1
    while i<=(len(time_range)-1):
        s=[]
        for j,tempo in enumerate(time_data['time']):
                if time_range[i-1]<time_data['time'][j]<=time_range[i]:
                    s.append(time_data[columnsNameList[0]][j])
                    np.mean(s)
        media.append(np.mean(s))
        i=i+1
    return media

# %%
##Create hard data from true model
columnsNameList = ['P1 : oil rate (m3/day)']
#obsData= -1*np.array(time_data['P1 : oil rate (m3/day)'])
obsValues = -1*np.array(media_function(time_range, time_data, columnsNameList))
dObs = obsValues.T.flatten()
dTime= np.array(time_range)

CeDiag =np.array(0.001*dObs[:]) #diagonal of the covariance matrix of observed data %1 of the oil rate
NTimesteps=len(dTime)
NWells=1
wells = ['P1']
wellDObs = np.repeat(wells, NTimesteps) #Configure the wells list

# %%
plt.plot(time_data['time'],-1*time_data['P1 : oil rate (m3/day)'])
plt.plot(time_range[1:], dObs)
plt.show()

# %%
#create a function to run ensemble simulations based on the prior ensemble
def RunModels(destDir, MScalar):
    for i, mMScalar in enumerate(MScalar):
        # create a model object
        m = ModelDA(frac_aper = mMScalar);
        # initialize the model
        m.init();
        m.params.max_ts = 10
        # run the model
        start = time.time()
        m.run(time_range[-1]);
        # get the data
        time_data = pd.DataFrame.from_dict(m.physics.engine.time_data)
         # write timedata to output file
        time_data.to_pickle(f'{destDir}\\data_model'+str(i)+'.pkl')  
        end = time.time()
        print(f'Elapsed time: {end - start} for model {str(i)}')

# %%
#Read the result from the model
def ReadModels(destDir, columnsNameList, Nd, Ne):
    D = np.empty([Nd, Ne])
    for i in range(Ne):
        dataSet = pd.read_pickle(f'{destDir}\\data_model'+str(i)+'.pkl') 
        model_value=np.array([])
        for name in columnsNameList:
            model_value = -1*np.array(media_function(time_range, dataSet, columnsNameList))
        
        d_models = model_value.T.flatten()    
           
        D[:,i] = d_models 

    return D

# %%
#functions to run ES-MDA
# Finds the truncation number - if using SVD
def FindTruncationNumber(Sigma, csi):
    temp = 0
    i = 0
    svSum = np.sum(Sigma)
    stopValue = svSum * csi
    for sv in np.nditer(Sigma):
        if (temp >= stopValue):
            break
        temp += sv
        i += 1
    return i

#Series of matriz treatments to make the process less memory consuming  - 
# see  Evensen, G., The Ensemble Kalman Filter: Theoretical Formulation and Practical Implementation, Ocean Dynamics (2003)
def CentralizeMatrix(M):
    meanMatrix = np.mean(M, axis=0)
    return M - meanMatrix


def UpdateModelLocalized(M, Psi, R, DobsD):
    DeltaM = CentralizeMatrix(M)

    K = DeltaM @ Psi
    Kloc = R * K ## Kalman gain with localization 
    return M + Kloc @ DobsD 

def UpdateModel(M, Psi, DobsD):
    DeltaM = CentralizeMatrix(M)

    X10 = Psi @ DobsD
    return M + DeltaM @ X10

# %%
#%%
#Calculate objetive function
def calcDataMismatchObjectiveFunction(dObs, D, CeInv):
    Ne = D.shape[1]
    Nd = D.shape[0]

    Od = np.empty(Ne)
    for i in range(Ne):
        dObsD = dObs - D[:,i].reshape(Nd,1)
        Od[i] = (dObsD.T) @ (CeInv[:,np.newaxis] * dObsD)/2
    return Od

# Replaces the pattern with the value in array cosrresponding its position.
# Only 1 group per line for now...
def ReplacePattern(matchobj, array):
    return f'{array[int(matchobj.group(1))]:.2f}'

# %%
#Building the prior ensemble based only on frac_aper 
# problem dimensions
#Ni = m_true.nx
#Nj = m_true.ny
NGrid = 0 # Ni * Nj
NScalar = 1 #we just considering one scalar as the parameter in the problem
Nm = NGrid + NScalar
Nd = len(dObs)* 1 #  timesteps * 1 well data
Ne = 30
NTimesteps = len(dTime)
NWells = 1 #we just considering one well

# svd truncation parameter for SVD 
csi = 0.99

# %%
#%%
#Generate the prior ensemble of scalar parameters
Em_frac_aper_het = np.random.normal(frac_aper_het.mean(), 2*frac_aper_het.mean(),Ne) 
Em_frac_aper_het = np.clip(Em_frac_aper_het, 1e-9,0.1)



# data colums
columnsNameList = ['P1 : oil rate (m3/day)']

MScalarPrior = Em_frac_aper_het
#print MScalarPrioir histogram

plt.hist(Em_frac_aper_het, bins=100)
plt.show()
#%%
curDir = os.getcwd()
srcDir =  f'{curDir}'
srcDir
# Out:
# 'c:\\Users\\bgy3\\OneDrive - PETROBRAS\\Documents\\PhD\\08.Simple-Fracture-Model-DARTS\\DA-DARTS-Naturally-Fractured-Reservoir-1'

# %%
# %%
#Run ES-MDA
#NOTE: REMEMBER TO ALLWAYS CHANGE destDir for different runs to avoid overwriting
SDiag = np.sqrt(CeDiag)
SInvDiag = np.power(SDiag, -1)

INd = np.eye(Nd)

MGrid = [] #not considering grid parameters

#Miterations = [] #defining this just to be able to plot later the fracture apertures
MScalar = MScalarPrior
alphas =[4., 4., 4., 4.]
l = 0

for alpha in alphas:
    # 2. Forecast

    # Generates the perturbed observations 
    z = np.random.normal(size=(Nd,Ne))
    DPObs = dObs[:,np.newaxis] + math.sqrt(alpha) * CeDiag[:,np.newaxis] * z

    # Run the simulations g(M) 
    destDir = f'{curDir}\\simulations_mainDA_deadoil_hetereogenous_fracture_angle_ref=45\\it{l}' 
    RunModels(destDir, MScalar)
    D = ReadModels(destDir, columnsNameList, Nd, Ne)
    if (l == 0):
        DPrior = D

    DobsD = DPObs - D

    # 4. Analysis
    # 4.1 Invert matrix C

    # Calculates DeltaD (12.5)
    meanMatrix = np.mean(D, axis=1)
    DeltaD = D - meanMatrix[:,np.newaxis]

    # Calculates CHat (12.10)
    CHat = SInvDiag[:,np.newaxis] * ( DeltaD @ DeltaD.T ) * SInvDiag[np.newaxis,:] + alpha * (Ne - 1) * INd

    # Calculates Gamma and X (12.18)
    U, SigmaDiag, Vt = np.linalg.svd(CHat)
    Nr = FindTruncationNumber(SigmaDiag, csi)

    GammaDiag = np.power(SigmaDiag[0:Nr], -1)
    X = SInvDiag[:,np.newaxis] * U[:,0:Nr]

    # Calculates M^a (12.21)
    X1 = GammaDiag[:,np.newaxis] * X.T
    X8 = DeltaD.T @ X
    X9 = X8 @ X1
    
    # subpart: for grid, use localization
    #MGrid = UpdateModelLocalized(MGrid, X9, Rmd, DobsD)

    # subpart: for scalars, don't use localization
    
    MScalar = UpdateModel(MScalar, X9, DobsD)
    MScalar[:] = np.clip(MScalar[:], 1e-9,0.1)
    
       
    l += 1
#%%
#MGridPost = MGrid
MScalarPost = MScalar
DPost = D
# Out:
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 1.9034538269042969 for model 0
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 2.5451557636260986 for model 1
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 1.844036340713501 for model 2
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 1.8852324485778809 for model 3
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 1.8941295146942139 for model 4
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 1.8410637378692627 for model 5
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 2.197042226791382 for model 6
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 2.3637499809265137 for model 7
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 2.74082088470459 for model 8
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 2.458012580871582 for model 9
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 1.9888601303100586 for model 10
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 2.065704822540283 for model 11
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 1.9958651065826416 for model 12
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 2.1646342277526855 for model 13
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 2.777709722518921 for model 14
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 2.0907394886016846 for model 15
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 2.43188214302063 for model 16
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 2.3510489463806152 for model 17
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 2.8825888633728027 for model 18
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 1.9919276237487793 for model 19
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 2.6995253562927246 for model 20
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 2.0168850421905518 for model 21
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 2.2036232948303223 for model 22
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 2.0024869441986084 for model 23
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 2.1323225498199463 for model 24
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 2.041135787963867 for model 25
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 2.304184913635254 for model 26
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 2.5447752475738525 for model 27
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 2.000993013381958 for model 28
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 2.0553998947143555 for model 29
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 2.769578456878662 for model 0
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 2.481009006500244 for model 1
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 2.6238481998443604 for model 2
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 2.584581136703491 for model 3
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 2.9447505474090576 for model 4
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 3.0711371898651123 for model 5
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 3.3208250999450684 for model 6
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 2.8317835330963135 for model 7
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 2.911017656326294 for model 8
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 2.739060401916504 for model 9
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 3.3506834506988525 for model 10
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 2.9612462520599365 for model 11
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 2.258014678955078 for model 12
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 3.1687989234924316 for model 13
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 2.9986536502838135 for model 14
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 2.5958380699157715 for model 15
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 2.6613008975982666 for model 16
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 2.5008273124694824 for model 17
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 2.5817930698394775 for model 18
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 2.8820672035217285 for model 19
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 2.8208067417144775 for model 20
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 2.616668462753296 for model 21
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 3.3289971351623535 for model 22
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 3.0120110511779785 for model 23
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 2.9069738388061523 for model 24
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 3.1986818313598633 for model 25
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 2.722198724746704 for model 26
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 2.342735528945923 for model 27
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 3.63784122467041 for model 28
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 3.5813374519348145 for model 29
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 2.830425500869751 for model 0
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 2.726203680038452 for model 1
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 3.712578296661377 for model 2
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 2.7581305503845215 for model 3
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 2.809725522994995 for model 4
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 3.3619041442871094 for model 5
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 2.9079883098602295 for model 6
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 2.7403953075408936 for model 7
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 3.3041157722473145 for model 8
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 3.55346417427063 for model 9
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 2.7040297985076904 for model 10
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 3.425840139389038 for model 11
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 3.536489725112915 for model 12
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 3.1728765964508057 for model 13
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 3.4087352752685547 for model 14
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 3.5709145069122314 for model 15
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 2.8194594383239746 for model 16
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 2.9021754264831543 for model 17
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 3.356884241104126 for model 18
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 2.787818193435669 for model 19
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 2.8273444175720215 for model 20
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 2.8700268268585205 for model 21
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 2.8231217861175537 for model 22
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 2.746399402618408 for model 23
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 3.2115366458892822 for model 24
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 2.920783281326294 for model 25
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 3.3021585941314697 for model 26
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 3.276594877243042 for model 27
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 2.9984772205352783 for model 28
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 3.1369926929473877 for model 29
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 3.2411561012268066 for model 0
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 3.638591766357422 for model 1
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 2.9094772338867188 for model 2
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 2.752518892288208 for model 3
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 3.4329402446746826 for model 4
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 3.1779184341430664 for model 5
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 2.8860156536102295 for model 6
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 2.9734673500061035 for model 7
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 2.980980396270752 for model 8
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 2.8350861072540283 for model 9
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 3.090033769607544 for model 10
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 2.866291046142578 for model 11
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8
#
# Elapsed time: 2.957817316055298 for model 12
# darts-package built on 27/03/2022 15:20:27 by SRV950$@SRV950 from d89b1a8

# %%
destDir
# Out:
# 'c:\\Users\\bgy3\\OneDrive - PETROBRAS\\Documents\\PhD\\08.Simple-Fracture-Model-DARTS\\DA-DARTS-Naturally-Fractured-Reservoir-1\\simulations_mainDA_deadoil_hetereogenous_fracture_angle_ref=45\\it3'

# %%
#%%
# Comparison of data mismatch objective function
# prior (l = 0)
CeInv = np.power(CeDiag, -1)
OPrior = calcDataMismatchObjectiveFunction(dObs[:,np.newaxis], DPrior, CeInv)
OPost = calcDataMismatchObjectiveFunction(dObs[:,np.newaxis], DPost, CeInv)

print(f'Mean: prior={np.mean(OPrior):.3e}, post={np.mean(OPost):.3e}')
print(f'Std: prior={np.std(OPrior, ddof=1):.3e}, post={np.std(OPost, ddof=1):.3e}')

fig, ax = plt.subplots()#plt.subplots(figsize=(Ne,Ne))
colors=['red','green']
x = np.stack((OPrior, OPost), axis=1)
#ax.hist(x, bins=40, alpha=0.8, color=colors, range=(x.min(),1e7))
ax.hist(x, bins=50, alpha=0.8, color=colors)
ax.set_title('Histograms Objetive Functions')
# Out:
# Mean: prior=6.953e+02, post=9.341e+02
# Std: prior=1.098e+02, post=1.756e+02
# Text(0.5, 1.0, 'Histograms Objetive Functions')

# %%
#Compare  the histograms of frac_aper prior and post

fig, ax = plt.subplots()#plt.subplots(figsize=(Ne,Ne))
colors=['red','green']
x = np.stack([MScalarPrior, MScalarPost], axis=1)
#ax.hist(x, bins=40, alpha=0.8, color=colors, range=(x.min(),1e7))
ax.hist(x, bins=50, alpha=0.8, color=colors)
ax.set_title('Histograms angles before and after history matching')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-ce5bab7af1c2> in <module>
#       5 x = np.stack([MScalarPrior, MScalarPost], axis=1)
#       6 #ax.hist(x, bins=40, alpha=0.8, color=colors, range=(x.min(),1e7))
# ----> 7 ax.hist(x, bins=50, alpha=0.8, color=colors)
#       8 ax.set_title('Histograms angles before and after history matching')
#       9
#
# c:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# c:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6578         input_empty = np.size(x) == 0
#    6579         # Massage 'x' for processing.
# -> 6580         x = cbook._reshape_2D(x, 'x')
#    6581         nx = len(x)  # number of datasets
#    6582
#
# c:\ProgramData\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py in _reshape_2D(X, name)
#    1384         return [np.reshape(x, -1) for x in X]
#    1385     else:
# -> 1386         raise ValueError("{} must have 2 or fewer dimensions".format(name))
#    1387
#    1388
#
# ValueError: x must have 2 or fewer dimensions

# %%
#%%
# Split the data into data array
wellDataPriorArray = np.split(DPrior, NWells)
wellDataPostArray = np.split(DPost, NWells)
wellDataObsArray = np.split(dObs, NWells)
wellDataObsErrorArray = np.split(CeDiag, NWells)

wellSubtitle = ['P1']
timeMonths = time_range[1:]/30.0


# get data and store in an array
prior = wellDataPriorArray # wellDataPriorArray[0:11:2]
post = wellDataPostArray # wellDataPostArray[0:11:2]
plotObsData = wellDataObsArray #wellDataObsArray[0:11:2]
errObsData = wellDataObsErrorArray #wellDataObsErrorArray[0:11:2]

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(25,8))
axFlat = ax.flatten()

axFlat[0].set_facecolor('white')
axFlat[0].plot(timeMonths, prior[0], color='#00FFFF', alpha=0.3)
axFlat[0].plot(timeMonths, post[0], color='b', alpha=0.3)
axFlat[0].errorbar(timeMonths, plotObsData[0], yerr=errObsData[0], fmt='_ r', capthick=1, capsize=0.1)
#axFlat[0].plot(timeMonths, plotObsData[i],color='red', alpha=0.5)
axFlat[0].set_title(wellSubtitle[0])
axFlat[0].set_xlabel('Time (months)')
axFlat[0].set_ylabel('oil rate (m3/day)')
axFlat[0].set_ylim([10, 30])


axFlat[1].plot(timeMonths, prior[1], color='#00FFFF', alpha=0.3)
axFlat[1].plot(timeMonths, post[1], color='b', alpha=0.3)
axFlat[1].scatter(timeMonths, plotObsData[1],color='red', alpha=0.5)
axFlat[1].set_title(wellSubtitle[0])
axFlat[1].set_xlabel('Time (months)')
axFlat[1].set_ylabel('oil rate (m3/day)')
#axFlat[1].set_ylim([342, 348])
fig.suptitle('P1 : oil rate (m3/day)')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-29-cb5f8cf79b21> in <module>
#      30
#      31
# ---> 32 axFlat[1].plot(timeMonths, prior[1], color='#00FFFF', alpha=0.3)
#      33 axFlat[1].plot(timeMonths, post[1], color='b', alpha=0.3)
#      34 axFlat[1].scatter(timeMonths, plotObsData[1],color='red', alpha=0.5)
#
# IndexError: list index out of range

# %%
MScalarPost.T.shape
# Out:
# (30, 1370)

# %%
# !jupyter nbconvert --to html mainDA_deadoil_angle_ref=45.ipynb
# Out:
# [NbConvertApp] Converting notebook mainDA_deadoil_angle_ref=45.ipynb to html
# [NbConvertApp] Writing 4914835 bytes to mainDA_deadoil_angle_ref=45.html

# %% [markdown]
# Evaluating the fracture apertures

# %%
#%%
import numpy as np
import meshio
import os
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import matplotlib.cm as cm

def calc_aperture(sigma_n):
    JRC = 7.225
    JCS = 17.5
    e_0 = 0.15
    v_m = -0.1032 - 0.0074 * JRC + 1.135 * (JCS / e_0) ** -0.251
    K_ni = -7.15 + 1.75 * JRC + 0.02 * JCS / e_0
    return e_0 - (1 / v_m + K_ni / sigma_n) ** -1


DIR = 'mesh_files'
scale = 15
mesh_file = os.path.join(DIR, 'mesh_{:}_real_6.msh'.format(scale))
mesh_data = meshio.read(mesh_file)
num_frac = mesh_data.cells[0].data.shape[0]
act_frac_sys = np.zeros((num_frac, 4))

for ii in range(num_frac):
    ith_line = mesh_data.points[mesh_data.cells[0].data[ii][:2]]
    act_frac_sys[ii, :2] = ith_line[0, :2]
    act_frac_sys[ii, 2:] = ith_line[1, :2]

# Plot to check if it worked:
#plt.figure()
#plt.plot(np.array([act_frac_sys[:, 0], act_frac_sys[:, 2]]),
#         np.array([act_frac_sys[:, 1], act_frac_sys[:, 3]]), color='black')
#plt.show()

epsilon = 1e-4
dx = act_frac_sys[:, 0] - act_frac_sys[:, 2] + epsilon * np.random.rand(num_frac)
dy = act_frac_sys[:, 1] - act_frac_sys[:, 3] + epsilon * np.random.rand(num_frac)
rotation = 0
angles = np.arctan(dy / dx) * 180 / np.pi + rotation + epsilon * np.random.rand(num_frac)
sigma_H = 5
sigma_h = 1
sigma_n = (sigma_H + sigma_h) / 2 + (sigma_H + sigma_h) / 2 * np.cos(angles * np.pi / 180 * 2)
factor_aper = 2.5
fracture_aper = frac_aper_het * factor_aper


m_to_mm = 1e3
min_aper = 1e-9 * m_to_mm
max_aper = 0.15 * 1e-3 * factor_aper * m_to_mm
fracs = fracture_aper * m_to_mm
fracs[fracs < min_aper] = min_aper
fracs[fracs > max_aper] = max_aper
norm = colors.Normalize(min_aper, max_aper)
colors_aper = cm.viridis(norm(fracs))
cutoff_value = min_aper

fig, ax = plt.subplots(1, 1, figsize=(10, 10), dpi=400, facecolor='w', edgecolor='k')
for ii in range(len(fracs)):
    if fracs[ii] >= cutoff_value:
        ax.plot(np.array([act_frac_sys[ii, 0], act_frac_sys[ii, 2]]),
                np.array([act_frac_sys[ii, 1], act_frac_sys[ii, 3]]),
                 color=colors_aper[ii, :-1])

ax.axis('equal')

for tick in ax.xaxis.get_major_ticks():
    tick.label.set_fontsize(14)
for tick in ax.yaxis.get_major_ticks():
    tick.label.set_fontsize(14)

sm = plt.cm.ScalarMappable(cmap=cm.viridis, norm=norm)
sm._A = []
cbar = plt.colorbar(sm)
cbar.set_label(r'Aperture, $a$ [mm]')

#plt.tight_layout()
#plt.savefig("variable_aperture_base_case_scale_{:}.pdf".format(scale))
#plt.show()

# %%
#%%
import numpy as np
import meshio
import os
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import matplotlib.cm as cm

def calc_aperture(sigma_n):
    JRC = 7.225
    JCS = 17.5
    e_0 = 0.15
    v_m = -0.1032 - 0.0074 * JRC + 1.135 * (JCS / e_0) ** -0.251
    K_ni = -7.15 + 1.75 * JRC + 0.02 * JCS / e_0
    return e_0 - (1 / v_m + K_ni / sigma_n) ** -1


DIR = 'mesh_files'
scale = 15
mesh_file = os.path.join(DIR, 'mesh_{:}_real_6.msh'.format(scale))
mesh_data = meshio.read(mesh_file)
num_frac = mesh_data.cells[0].data.shape[0]
act_frac_sys = np.zeros((num_frac, 4))

for ii in range(num_frac):
    ith_line = mesh_data.points[mesh_data.cells[0].data[ii][:2]]
    act_frac_sys[ii, :2] = ith_line[0, :2]
    act_frac_sys[ii, 2:] = ith_line[1, :2]

# Plot to check if it worked:
#plt.figure()
#plt.plot(np.array([act_frac_sys[:, 0], act_frac_sys[:, 2]]),
#         np.array([act_frac_sys[:, 1], act_frac_sys[:, 3]]), color='black')
#plt.show()

epsilon = 1e-4
dx = act_frac_sys[:, 0] - act_frac_sys[:, 2] + epsilon * np.random.rand(num_frac)
dy = act_frac_sys[:, 1] - act_frac_sys[:, 3] + epsilon * np.random.rand(num_frac)
rotation = 0
angles = np.arctan(dy / dx) * 180 / np.pi + rotation + epsilon * np.random.rand(num_frac)
sigma_H = 5
sigma_h = 1
sigma_n = (sigma_H + sigma_h) / 2 + (sigma_H + sigma_h) / 2 * np.cos(angles * np.pi / 180 * 2)
factor_aper = 2.5
fracture_aper = MScalarPrior[0] * factor_aper


m_to_mm = 1e3
min_aper = 1e-9 * m_to_mm
max_aper = 0.15 * 1e-3 * factor_aper * m_to_mm
fracs = fracture_aper * m_to_mm
fracs[fracs < min_aper] = min_aper
fracs[fracs > max_aper] = max_aper
norm = colors.Normalize(min_aper, max_aper)
colors_aper = cm.viridis(norm(fracs))
cutoff_value = min_aper

fig, ax = plt.subplots(1, 1, figsize=(10, 10), dpi=400, facecolor='w', edgecolor='k')
for ii in range(len(fracs)):
    if fracs[ii] >= cutoff_value:
        ax.plot(np.array([act_frac_sys[ii, 0], act_frac_sys[ii, 2]]),
                np.array([act_frac_sys[ii, 1], act_frac_sys[ii, 3]]),
                 color=colors_aper[ii, :-1])

ax.axis('equal')

for tick in ax.xaxis.get_major_ticks():
    tick.label.set_fontsize(14)
for tick in ax.yaxis.get_major_ticks():
    tick.label.set_fontsize(14)

sm = plt.cm.ScalarMappable(cmap=cm.viridis, norm=norm)
sm._A = []
cbar = plt.colorbar(sm)
cbar.set_label(r'Aperture, $a$ [mm]')

#plt.tight_layout()
#plt.savefig("variable_aperture_base_case_scale_{:}.pdf".format(scale))
#plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-f6e9f1aa91ef> in <module>
#      58 fig, ax = plt.subplots(1, 1, figsize=(10, 10), dpi=400, facecolor='w', edgecolor='k')
#      59 for ii in range(len(fracs)):
# ---> 60     if fracs[ii] >= cutoff_value:
#      61         ax.plot(np.array([act_frac_sys[ii, 0], act_frac_sys[ii, 2]]),
#      62                 np.array([act_frac_sys[ii, 1], act_frac_sys[ii, 3]]),
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
#%%
import numpy as np
import meshio
import os
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import matplotlib.cm as cm

def calc_aperture(sigma_n):
    JRC = 7.225
    JCS = 17.5
    e_0 = 0.15
    v_m = -0.1032 - 0.0074 * JRC + 1.135 * (JCS / e_0) ** -0.251
    K_ni = -7.15 + 1.75 * JRC + 0.02 * JCS / e_0
    return e_0 - (1 / v_m + K_ni / sigma_n) ** -1


DIR = 'mesh_files'
scale = 15
mesh_file = os.path.join(DIR, 'mesh_{:}_real_6.msh'.format(scale))
mesh_data = meshio.read(mesh_file)
num_frac = mesh_data.cells[0].data.shape[0]
act_frac_sys = np.zeros((num_frac, 4))

for ii in range(num_frac):
    ith_line = mesh_data.points[mesh_data.cells[0].data[ii][:2]]
    act_frac_sys[ii, :2] = ith_line[0, :2]
    act_frac_sys[ii, 2:] = ith_line[1, :2]

# Plot to check if it worked:
#plt.figure()
#plt.plot(np.array([act_frac_sys[:, 0], act_frac_sys[:, 2]]),
#         np.array([act_frac_sys[:, 1], act_frac_sys[:, 3]]), color='black')
#plt.show()

epsilon = 1e-4
dx = act_frac_sys[:, 0] - act_frac_sys[:, 2] + epsilon * np.random.rand(num_frac)
dy = act_frac_sys[:, 1] - act_frac_sys[:, 3] + epsilon * np.random.rand(num_frac)
rotation = 0
angles = np.arctan(dy / dx) * 180 / np.pi + rotation + epsilon * np.random.rand(num_frac)
sigma_H = 5
sigma_h = 1
sigma_n = (sigma_H + sigma_h) / 2 + (sigma_H + sigma_h) / 2 * np.cos(angles * np.pi / 180 * 2)
factor_aper = 2.5
fracture_aper = aperture_vec(math.degrees(MScalarPost[0])) * factor_aper


m_to_mm = 1e3
min_aper = 1e-9 * m_to_mm
max_aper = 0.15 * 1e-3 * factor_aper * m_to_mm
fracs = fracture_aper * m_to_mm
fracs[fracs < min_aper] = min_aper
fracs[fracs > max_aper] = max_aper
norm = colors.Normalize(min_aper, max_aper)
colors_aper = cm.viridis(norm(fracs))
cutoff_value = min_aper

fig, ax = plt.subplots(1, 1, figsize=(10, 10), dpi=400, facecolor='w', edgecolor='k')
for ii in range(len(fracs)):
    if fracs[ii] >= cutoff_value:
        ax.plot(np.array([act_frac_sys[ii, 0], act_frac_sys[ii, 2]]),
                np.array([act_frac_sys[ii, 1], act_frac_sys[ii, 3]]),
                 color=colors_aper[ii, :-1])

ax.axis('equal')

for tick in ax.xaxis.get_major_ticks():
    tick.label.set_fontsize(14)
for tick in ax.yaxis.get_major_ticks():
    tick.label.set_fontsize(14)

sm = plt.cm.ScalarMappable(cmap=cm.viridis, norm=norm)
sm._A = []
cbar = plt.colorbar(sm)
cbar.set_label(r'Aperture, $a$ [mm]')

#plt.tight_layout()
#plt.savefig("variable_aperture_base_case_scale_{:}.pdf".format(scale))
#plt.show()

# %%
#%%
# Comparison of data mismatch objective function
CeInv_qw = np.power(CeDiag_qw, -1)
OPrior_qw = calcDataMismatchObjectiveFunction(dObs_qw[:,np.newaxis],D_qw_prior, CeInv_qw)
OPost_qw = calcDataMismatchObjectiveFunction(dObs_qw[:,np.newaxis],D_qw, CeInv_qw)
print(f'Mean: prior={np.mean(OPrior_qw):.3e}, post={np.mean(OPost_qw):.3e}')
print(f'Std: prior={np.std(OPrior_qw, ddof=1):.3e}, post={np.std(OPost_qw, ddof=1):.3e}')

fig, ax = plt.subplots()#plt.subplots(figsize=(Ne,Ne))
colors=['red','green']
x = np.stack((OPrior_qw, OPost_qw), axis=1)
#ax.hist(x, bins=40, alpha=0.8, color=colors, range=(x.min(),1e7))
ax.hist(x, bins=50, alpha=0.8, color=colors)
ax.set_title('Histograms Objetive Functions for water rate')
# Out:
# Mean: prior=8.654e+07, post=1.637e+04
# Std: prior=1.268e+08, post=4.385e+04
# Text(0.5, 1.0, 'Histograms Objetive Functions for water rate')

# %% [markdown]
# Plot of angles using rose diagram

# %%
# Store the angles of the fracture-network:
dx_raw = act_frac_sys_raw[:, 0] - act_frac_sys_raw[:, 2] - 1e-10 * np.random.randn(act_frac_sys_raw.shape[0],)
dy_raw = act_frac_sys_raw[:, 1] - act_frac_sys_raw[:, 3] - 1e-10 * np.random.randn(act_frac_sys_raw.shape[0],)
angles_raw = np.arctan(dx_raw / dy_raw) * 180 / np.pi
angles_raw += 90
tot_segm_length_raw = np.sum(length_segms_raw)

# Bin into 10 degrees bins (i.e., 18 bins total, with center 0, 10, ..., 170)
NR_BINS = 18
angles_matrix_count_raw = np.zeros((18,))
for ith_bin in range(NR_BINS):
    left = 180 / NR_BINS * (ith_bin - 0.5)
    right = 180 / NR_BINS * (ith_bin + 0.5)
    indices_raw = np.where((left < angles_raw) * (angles_raw < right))[0]
    angles_matrix_count_raw[ith_bin] = np.sum(length_segms_raw[indices_raw]) / tot_segm_length_raw

# %%
# Plot bar:
complete_360 = True

if complete_360:
    N = 18 * 2
    range_angles = 2 * np.pi
else:
    N = 18 * 1
    range_angles = 1 * np.pi

theta = np.linspace(0, range_angles, N, endpoint=False)

# Plot histograms:
SCALES_ANGLES = ['4', '8', '16', '32', '64', '128']
ncols = 3
nrows = int(np.ceil(len(SCALES_ANGLES) / ncols))
fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(15, 10), subplot_kw=dict(projection='polar'))
count = 0

for ii in range(nrows):
    for jj in range(ncols):
        if count < len(SCALES_ANGLES):
            ax = axes[ii][jj]
            if complete_360:
                radii_raw = np.hstack((angles_matrix_count_raw, angles_matrix_count_raw)) * 100
                radii_clean = np.hstack((dict_angles_clean[SCALES_ANGLES[count]], dict_angles_clean[SCALES_ANGLES[count]])) * 100
            else:
                radii_raw = angles_matrix_count_raw * 100
                radii_clean = dict_angles_clean[SCALES_ANGLES[count]] * 100

            width = range_angles / N
            ax.bar(theta, radii_raw, width=width, color='blue', alpha=0.9, label='Raw')
            ax.bar(theta, radii_clean, width=width, color='red', alpha=0.5, label='Clean')

            ax.set_alpha(0.75)
            # ax.set_rasterized(True)

            if count == 0:
                ax.legend(prop=font_dict_legend, facecolor='white', framealpha=1)

            ax.set_title('$l_f = $' + SCALES_ANGLES[count], fontdict=font_dict_title)
            count += 1

for ii in range(nrows):
    for jj in range(ncols):
        for tick in axes[ii][jj].xaxis.get_major_ticks():
            tick.label.set_fontsize(12)

        for tick in axes[ii][jj].yaxis.get_major_ticks():
            tick.label.set_fontsize(12)

plt.tight_layout()
# plt.suptitle('Angle distribution')
# plt.show()
plt.savefig(network + "_angle_distribution.png")
plt.savefig(network + "_angle_distribution.pdf")
